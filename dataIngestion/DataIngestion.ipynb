# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader("index.txt")
loader.load()
# Out:
# [Document(metadata={'source': 'index.txt'}, page_content='Modda gudu \nHow are you guys \nHope you are well ')]

# %%
from langchain_community.document_loaders import WebBaseLoader

page_url = "https://sports.ndtv.com/cricket/players/967-virat-kohli-playerprofile/news"

loader = WebBaseLoader(web_paths=[page_url])
loader.load()
# Out:
# [Document(metadata={'source': 'https://sports.ndtv.com/cricket/players/967-virat-kohli-playerprofile/news', 'title': 'Virat Kohli News : Read all Latest and Breaking News of Virat Kohli – NDTV Sports', 'description': ' Find latest news around Virat Kohli, Cricket Player from India at NDTV Sports for more update and information log on to sports.ndtv.com.', 'language': 'No language found.'}, page_content='\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nVirat Kohli News : Read all Latest and Breaking News of Virat Kohli – NDTV Sports\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\r\n                                        NDTV\r\n                                    \n\n\n\r\n                                        WORLD\r\n                                    \n\n\n\r\n                                        PROFIT\r\n                                    \n\n\n\r\n                                        हिंदी\r\n                                    \n\n\n\r\n                                        WPL 2025\r\n                                    \n\n\n\r\n                                        MOVIES\r\n                                    \n\n\n\r\n                                        FOOD\r\n                                    \n\n\n\r\n                                        LIFESTYLE\r\n                                    \n\n\n\r\n                                        HEALTH\r\n                                    \n\n\n\r\n                                        SWASTH\r\n                                    \n\n\n\r\n                                        TECH\r\n                                    \n\n\n\r\n                                        GAMES\r\n                                    \n\n\n\r\n                                        BIG BONUS\r\n                                    \n\n\n\r\n                                        SHOPPING\r\n                                    \n\n\n\r\n                                        APPS\r\n                                    \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nDon\'t Miss\n\n\n\n\nLewis Hamilton Unharmed After Crashing During Ferrari Barcelona Test\n\n\n\n\nCarlos Alcaraz Says Jannik Sinner Is The Man To Beat In Men\'s Tennis\n\n\n\n\nSpanish Football Still Mired In Scandal As Luis Rubiales Trial Begins\n\n\n\n\nWWE Scandal: Brock Lesnar Named In Lawsuit Against Vince McMahon\n\n\n\n\n\n\n\n\nAdvertisement\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\r\n                            ENG\r\n                            \n\n\n\n\n\n\nSelect Languages\n\nहिंदी | Hindi\n\n\n\n\n\n\n\n\n\n\n\nCricket\n\n\n\nFootball\n\n\n\nWebstories\n\n\n\nFormula 1 \n\n\n\nTennis\n\n\n\n\nGolf\n\n\n\nBadminton\n\n\n\n\n\n\n\n\n\nBadminton\n\n\nKabaddi\n\n\nNBA\n\n\nBoxing\n\n\nAthletics\n\n\nChess\n\n\nSwimming\n\n\nShooting\n\n\nWrestling\n\n\nTable tennis\n\n\nOthersports\n\n\n\n\n\n\n\n\n\nLogin\n\n\n\n\n\n\n\n\n\nDark / Light mode\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSelect Language \n\n\n\n\nLanguages\n\nहिंदी | Hindi\n\n\n\n\n\n\n\n\n\n\n\n\n\nDark / Light mode\n\n\n\n\n\n\nSearch\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nFeatured Links\n\n\n\n\nChampions Trophy 2025\n\n\nCT Schedule\n\n\nEPL Table\n\n\nEPL Schedule\n\n\n\n\n\nFeatured Sports\n\n\n\n\n\n\r\n                                        Cricket\r\n                                    \n\n\n\n\n\n\r\n                                        Football\r\n                                    \n\n\n\n\n\n\r\n                                        Formula 1\r\n                                    \n\n\n\n\n\n\r\n                                        Tennis\r\n                                    \n\n\n\n\n\n\r\n                                        Hockey\r\n                                    \n\n\n\n\n\n\r\n                                        Golf\r\n                                    \n\ ...

# %%
doc
# Out:
# Document(metadata={'source': 'https://sports.ndtv.com/cricket/players/967-virat-kohli-playerprofile/news', 'title': 'Virat Kohli News : Read all Latest and Breaking News of Virat Kohli – NDTV Sports', 'description': ' Find latest news around Virat Kohli, Cricket Player from India at NDTV Sports for more update and information log on to sports.ndtv.com.', 'language': 'No language found.'}, page_content='\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nVirat Kohli News : Read all Latest and Breaking News of Virat Kohli – NDTV Sports\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\r\n                                        NDTV\r\n                                    \n\n\n\r\n                                        WORLD\r\n                                    \n\n\n\r\n                                        PROFIT\r\n                                    \n\n\n\r\n                                        हिंदी\r\n                                    \n\n\n\r\n                                        WPL 2025\r\n                                    \n\n\n\r\n                                        MOVIES\r\n                                    \n\n\n\r\n                                        FOOD\r\n                                    \n\n\n\r\n                                        LIFESTYLE\r\n                                    \n\n\n\r\n                                        HEALTH\r\n                                    \n\n\n\r\n                                        SWASTH\r\n                                    \n\n\n\r\n                                        TECH\r\n                                    \n\n\n\r\n                                        GAMES\r\n                                    \n\n\n\r\n                                        BIG BONUS\r\n                                    \n\n\n\r\n                                        SHOPPING\r\n                                    \n\n\n\r\n                                        APPS\r\n                                    \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nDon\'t Miss\n\n\n\n\nLewis Hamilton Unharmed After Crashing During Ferrari Barcelona Test\n\n\n\n\nCarlos Alcaraz Says Jannik Sinner Is The Man To Beat In Men\'s Tennis\n\n\n\n\nSpanish Football Still Mired In Scandal As Luis Rubiales Trial Begins\n\n\n\n\nWWE Scandal: Brock Lesnar Named In Lawsuit Against Vince McMahon\n\n\n\n\n\n\n\n\nAdvertisement\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\r\n                            ENG\r\n                            \n\n\n\n\n\n\nSelect Languages\n\nहिंदी | Hindi\n\n\n\n\n\n\n\n\n\n\n\nCricket\n\n\n\nFootball\n\n\n\nWebstories\n\n\n\nFormula 1 \n\n\n\nTennis\n\n\n\n\nGolf\n\n\n\nBadminton\n\n\n\n\n\n\n\n\n\nBadminton\n\n\nKabaddi\n\n\nNBA\n\n\nBoxing\n\n\nAthletics\n\n\nChess\n\n\nSwimming\n\n\nShooting\n\n\nWrestling\n\n\nTable tennis\n\n\nOthersports\n\n\n\n\n\n\n\n\n\nLogin\n\n\n\n\n\n\n\n\n\nDark / Light mode\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSelect Language \n\n\n\n\nLanguages\n\nहिंदी | Hindi\n\n\n\n\n\n\n\n\n\n\n\n\n\nDark / Light mode\n\n\n\n\n\n\nSearch\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nFeatured Links\n\n\n\n\nChampions Trophy 2025\n\n\nCT Schedule\n\n\nEPL Table\n\n\nEPL Schedule\n\n\n\n\n\nFeatured Sports\n\n\n\n\n\n\r\n                                        Cricket\r\n                                    \n\n\n\n\n\n\r\n                                        Football\r\n                                    \n\n\n\n\n\n\r\n                                        Formula 1\r\n                                    \n\n\n\n\n\n\r\n                                        Tennis\r\n                                    \n\n\n\n\n\n\r\n                                        Hockey\r\n                                    \n\n\n\n\n\n\r\n                                        Golf\r\n                                    \n\n ...

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("Attention+Mechanism.pdf")
loader.load()
# Out:
# [Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'Attention+Mechanism.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'Attention+Mechanism.pdf', 'total_pages': 5, 'page': 1, 'page_label': '2'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'Attention+Mechanism.pdf', 'total_pages': 5, 'page': 2, 'page_label': '3'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'Attention+Mechanism.pdf', 'total_pages': 5, 'page': 3, 'page_label': '4'}, page_content=''),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'PyPDF', 'creationdate': '', 'source': 'Attention+Mechanism.pdf', 'total_pages': 5, 'page': 4, 'page_label': '5'}, page_content='')]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
